# %% [markdown]
# # Question No. - 01

# %%
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException ,NoSuchElementException
import requests
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome()
driver.get("https://www.amazon.in/")

# %%
Product_Name=driver.find_element(By.ID,"twotabsearchtextbox")
Product_Name.send_keys('Guitars')

# %%
search=driver.find_element(By.ID,"nav-search-submit-text")
search.click()

# %% [markdown]
# # Question No. -02

# %%
Brand_Name=[]
Name_of_Product=[]
Price=[]
Return_Exchange=[]
Expected_Delivery=[]
Availability=[]
url=[]

# %%
tags =driver.find_elements(By.CLASS_NAME,"a-size-mini a-spacing-none a-color-base s-line-clamp-4")
for i in tags:
    title=i.text
    Brand_Name.append(title)

# %%
Brand_Name
# Out:
# {'BLUEBERRY 38C, Acoustic Guitar Kit with Bag, Strap, One Pack Strings And Picks - 38 Inch (Natural)',
#  'BLUEBERRY B-D38, Acoustic Guitar Kit Inbuilt Truss Rod with Bag, Strap, One Pack Strings And Picks - 38 Inch (Natural)',
#  'BLUEBERRY D38S, Acoustic Guitar Kit Inbuilt Truss Rod, with Bag, Belt, One Pack Strings And Picks - 38 Inch (Brown)',
#  'BLUEBERRY R-40, Sapele Wood Acoustic Guitar Kit with Inbuilt Truss Rod, Bag, Strap, One Pack Strings And Picks - 40 Inch (Classic Brown)',
#  'BLUEBERRY VIP 341, Sapele Natural Wood Finsh Acoustic Guitar Kit With Bag, Belt, String Sets And 2 Picks - 34 Inch (Ntural)',
#  'BLUEBERRY VIP-340, Acoustic Guitar Kit With Bag, Belt, String Set and 2 Picks - 34 Inch (Black)',
#  'BLUEBERRY, B-38C Acoustic Guitar Kit with Bag, Strap, One Pack Strings And 2 Picks - 38 Inch (Retro BlACK)',
#  'BLUEBERRY, VIP-385, Acoustic Guitar Basswood, Ash With Bag, Belt, String Set and 2 Picks - 38 Inch (Natural)',
# ...

# %%
len(Brand_Name)
# Out:
# 139

# %%
tags_1 =driver.find_elements(By.CLASS_NAME,'a-price-whole')
for i in tags_1:
    title=i.text
    Price.append(title)

# %%
Price = {x for x in Price if x != ''}

# %%
len(Price)
# Out:
# 32

# %% [markdown]
# # Question No. -08

# %%
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException ,NoSuchElementException
import requests
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome()
driver.get("https://www.youtube.com/watch?v=C8fTWGeua3s")

# %%
Comments=[]

# %%
comments_tags = driver.find_elements(By.XPATH,'//span[@class="yt-core-attributed-string yt-core-attributed-string--white-space-pre-wrap"]')
for i in comments_tags:
    tags=i.text
    Comments.append(tags)

# %%
Comments[13:513]
# Out:
# ['That lady was wandering throughout the video trying to find her room in this large house!! Hope atleast by now she has found her room. God bless',
#  "The idea of bringing in the elements of temple into a house architecture is something that I've dreamt of since I was young. Seeing this project is quite exhilarating and blissfully relaxing at the same time.  Thanks to the architect for thinking of this and Buildofy to bring it to us for us to enjoy! Keep doing awesome!",
#  'Job well done, one of the best homes. .. any house which incorporates 5 elements of nature - Earth, Air, water , space and fire turns out to be great..',
#  'being  an \narchitect is not a joke. hats off to those masterminds',
#  'One of the best part was that they gave credit to the team members. And the elegance in design is that they made luxury look humble. Bravo!',
# ...

# %% [markdown]
# # Question No. -09

# %%
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException ,NoSuchElementException
import requests
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome()
driver.get("https://www.hostelworld.com/")

# %%
Location_Name=driver.find_element(By.CLASS_NAME,"native-input")
Location_Name.send_keys('London')

# %%
search=driver.find_element(By.CLASS_NAME,"icon-container")
search.click()

# %%
Hostel_Name=[]
D_Citycentre=[]
Ratings=[]
Privateroom_Price=[]
Dorm_room_Price=[]
total_reviews=[]

# %%
name_tags =driver.find_elements(By.CLASS_NAME,"property-name")
for i in name_tags:
    title=i.text
    Hostel_Name.append(title)

# %%
Hostel_Name
# Out:
# ['Palmers Lodge - Swiss Cottage',
#  "St Christopher's Village",
#  "Wombat's City Hostel London",
#  'Palmers Lodge - Swiss Cottage',
#  'Onefam Notting Hill',
#  'Urbany Hostel London',
#  'Onefam Waterloo',
#  'NX London Hostel',
#  "St Christopher's Village",
#  'Clink261',
#  'Generator London',
#  'No.8 Seven Sisters',
#  'Astor Museum Inn',
#  'Safestay London Elephant & Castle',
#  'No.8 Willesden Hostel London',
#  'Destinations Hostels @ The Gallery',
#  'Smart Russell Square Hostel',
#  'Queen Elizabeth Chelsea',
#  'Astor Hyde Park',
#  'London Backpackers',
#  'Hostelle - women only hostel London',
#  'Phoenix Hostel',
#  'Smart Camden Inn Hostel',
#  'Saint James Backpackers',
#  'YHA London Oxford Street',
#  'Smart Hyde Park Inn Hostel',
#  'Barmy Badger Backpackers',
#  "St Christopher's Hammersmith",
#  'Astor Victoria',
#  'Kabannas London St Pancras',
#  "St Christopher's Inn - London Bridge",
#  "St Christopher's Camden",
#  'Palmers Lodge - Swiss Cottage',
# ...

# %%
Citycentre =driver.find_elements(By.XPATH,'//span[@class="distance-description"]')
for i in Citycentre:
    title=i.text
    D_Citycentre.append(title)

# %%
D_Citycentre
# Out:
# ['- 3.6km from city centre',
#  '- 6.5km from city centre',
#  '- 5.5km from city centre',
#  '- 5.4km from city centre',
#  '- 0.7km from city centre',
#  '- 6.1km from city centre',
#  '- 1.8km from city centre',
#  '- 3.2km from city centre',
#  '- 3km from city centre',
#  '- 9km from city centre',
#  '- 2.2km from city centre',
#  '- 1.7km from city centre',
#  '- 10km from city centre',
#  '- 1.7km from city centre',
#  '- 2.6km from city centre',
#  '- 5.7km from city centre',
#  '- 4.3km from city centre',
#  '- 11.9km from city centre',
#  '- 5.1km from city centre',
#  '- 4.2km from city centre',
#  '- 4.4km from city centre',
#  '- 5.5km from city centre',
#  '- 2.1km from city centre',
#  '- 5km from city centre',
#  '- 5.5km from city centre',
#  '- 7.5km from city centre',
#  '- 1.8km from city centre',
#  '- 3.3km from city centre',
#  '- 1.8km from city centre',
#  '- 4.3km from city centre',
#  '- 3.6km from city centre',
#  '- 6.5km from city centre',
# ...

# %%
ratings_tags =driver.find_elements(By.XPATH,'//span[@class="number"]')
for i in ratings_tags:
    title=i.text
    Ratings.append(title)

# %%
Ratings
# Out:
# ['8.7',
#  '7.7',
#  '9.3',
#  '8.7',
#  '9.7',
#  '9.6',
#  '9.5',
#  '8.8',
#  '7.7',
#  '8.2',
#  '7.2',
#  '7.7',
#  '8.9',
#  '7.1',
#  '7.0',
#  '9.1',
#  '7.5',
#  '8.0',
#  '7.9',
#  '8.5',
#  '8.5',
#  '7.1',
#  '8.8',
#  '8.0',
#  '9.2',
#  '7.7',
#  '9.2',
#  '7.8',
#  '7.0',
#  '8.4',
#  '7.4',
#  '8.2']

# %%
private_room_tags =driver.find_elements(By.CLASS_NAME,"current")
for i in private_room_tags:
    title=i.text
    Privateroom_Price.append(title)

# %%
Privateroom_Price
# Out:
# ['€183',
#  '€44',
#  '€109',
#  '€33',
#  '€185',
#  '€77',
#  '€160',
#  '€51',
#  '€48',
#  '€32',
#  '€85',
#  '€25',
#  '€35',
#  '€149',
#  '€35',
#  '€15',
#  '€30',
#  '€224',
#  '€25',
#  '€17',
#  '€48',
#  '€28',
#  '€22',
#  '€26',
#  '€94',
#  '€26',
#  '€43',
#  '€23',
#  '€30',
#  '€39',
#  '€115',
#  '€191',
#  '€24',
#  '€138',
#  '€45',
#  '€93',
#  '€22',
#  '€99',
#  '€24',
#  '€201',
#  '€50',
#  '€93',
#  '€31',
#  '€27']

# %%
total_reviews =driver.find_elements(By.CLASS_NAME,'review')
for i in total_reviews:
    title=i.text
    total_reviews.append(title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 3
#       1 total_reviews =driver.find_elements(By.CLASS_NAME,'review')
#       2 for i in total_reviews:
# ----> 3     title=i.text
#       4     total_reviews.append(title)
#
# AttributeError: 'str' object has no attribute 'text'

# %% [markdown]
# # Question No. -06

# %%
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException ,NoSuchElementException
import requests
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')

driver = webdriver.Chrome()
driver.get("https://www.digit.in/")

# %%
Laptops=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div/div/div[2]/form/input[1]')
Laptops.send_keys('gaming laptops')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div/div/div[2]/form/button/i')
search.click()

# %%
Name=[]
Price=[]
Rating=[]

# %%
Name_tags =driver.find_elements(By.XPATH,'//h3[@class=" text-clamp text-clamp-2"]')
for i in Name_tags:
    title=i.text
    Name.append(title)

# %%
Price_tags =driver.find_elements(By.CLASS_NAME,'price')    
for i in Price_tags:
    try:
        title=i.text
        Price.append(title)
    except NoSuchElementException:
        Price.append("Not Present")

# %%
Name
# Out:
# ['Lenovo IdeaPad Gaming 3 15IAH7',
#  'Lenovo IdeaPad Gaming 3i',
#  'Alienware x14 Gaming Laptop',
#  'MSI Gaming Raider',
#  'Lenovo Legion 7',
#  'Dell 15 (2021) i5-10200H']

# %%
Price
# Out:
# ['₹79,831.00', '₹174,990.00', '₹328,800.00']

# %%
Rating_tags =driver.find_elements(By.CLASS_NAME,"rh_woo_star")
for i in Rating_tags:
    title=i.text
    Rating.append(title)

# %%
Rating
# Out:
# ['★★★★★', '★★★★★', '★★★★★']
